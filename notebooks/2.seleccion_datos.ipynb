# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_csv('../datos/Dataframe_cols_unificadas.csv')
df.head(2)
# Out:
#    Unnamed: 0  time    age gender         Q3                 Q4  \
# 0           0   910  50-54    Man      India  Bachelor’s degree
# 1           1   784  50-54    Man  Indonesia    Master’s degree
#
#                         Q5          Q6      Q8  \
# 0                    Other  5-10 years  Python
# 1  Program/Project Manager   20+ years  Python
#
#                                                  Q11  \
# 0                                           A laptop
# 1  A cloud computing platform (AWS, Azure, GCP, h...
#
#                          Q20                   Q21  Q22  \
# 0  Manufacturing/Fabrication      50-249 employees  3-4
# 1  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23            Q25  Q33  \
# 0                      No (we do not use ML methods)  25,000-29,999  NaN
# 1  We are exploring ML methods (and may one day p...  60,000-69,999  NaN
#
# ...

# %%
# Decidimos borrar columnas que no vamos a utilizar
df.drop(['Unnamed: 0', 'time', 'Q8', 'Q12', 'Q16', 'Q22', 'Q23', 'Q28'], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#      age gender         Q3                 Q4                       Q5  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
#
#            Q6                                                Q11  \
# 0  5-10 years                                           A laptop
# 1   20+ years  A cloud computing platform (AWS, Azure, GCP, h...
#
#                          Q20                   Q21            Q25  Q33  \
# 0  Manufacturing/Fabrication      50-249 employees  25,000-29,999  NaN
# 1  Manufacturing/Fabrication  1000-9,999 employees  60,000-69,999  NaN
#
#                    Q7                           Q9  \
# 0           Python, R                  Vim / Emacs
# 1   SQL, C, C++, Java   Notepad++,Jupyter Notebook
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
# ...

# %%
# Renombramos algunas columnas importantes con las que vamos a trabajar
df.rename(columns = {'age': 'edad', 'gender': 'genero','Q3': 'paises', 'Q4': 'titulo_academico', 'Q5': 'puesto_trabajo', 'Q6': 'años_experiencia','Q7': 'lenguaje_programacion', 'Q9': 'entorno_desarrollo',
                           'Q11': 'plataforma_informatica', 'Q14': 'libreria_visualizacion', 'Q20': 'sector_laboral', 'Q21': 'tamaño_empresa', 'Q24': 'funciones_puesto', 
                           'Q25': 'salario', 'Q33': 'servidor_datos', 'Q34': 'herramienta_BI', 'Q39': 'herramienta_publicacion' , 'Q41': 'herramienta_analisis'}, inplace = True)

# %%
df.head()
# Out:
#     edad genero     paises   titulo_academico           puesto_trabajo  \
# 0  50-54    Man      India  Bachelor’s degree                    Other
# 1  50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2  22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3  45-49    Man     Mexico    Doctoral degree       Research Scientist
# 4  45-49    Man      India    Doctoral degree                    Other
#
#   años_experiencia                             plataforma_informatica  \
# 0       5-10 years                                           A laptop
# 1        20+ years  A cloud computing platform (AWS, Azure, GCP, h...
# 2        1-3 years                                           A laptop
# 3        20+ years  A cloud computing platform (AWS, Azure, GCP, h...
# 4        < 1 years  A cloud computing platform (AWS, Azure, GCP, h...
#
#               sector_laboral        tamaño_empresa        salario  \
# ...

# %%
df.shape
# Out:
# (25973, 16)

# %%
# Guardamos el dataframe modificado
df.to_csv('../datos/Dataframe_seleccion.csv')
