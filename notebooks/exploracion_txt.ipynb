# %%
import numpy as np
import pandas as pd

# %%
#Dataframe de txt
df_txt = pd.read_csv('promoE-modulo2-equipo1-VeronicaCatalinaYencySofia/Archivos/data_txt_clean.txt', delimiter=';', index_col=0)
df_txt.head(1)
# Out:
#           Q3                 Q4     Q5          Q6      Q8       Q11  \
# index
# 0      India  Bachelor’s degree  Other  5-10 years  Python  A laptop
#
#              Q13         Q15                        Q20               Q21  \
# index
# 0      2-5 times  5-10 years  Manufacturing/Fabrication  50-249 employees
#
#        ...                                                Q41         Q7  \
# index  ...
# 0      ...  Local development environments (RStudio, Jupyt...  Python, R
#
#                  Q9                 Q12  \
# index
# 0       Vim / Emacs  Google Cloud TPUs
#
#                                                      Q14  \
# index
# 0       Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                      Q16  \
# index
# 0      Scikit-learn , TensorFlow ,Caret
#
#                                                      Q17  \
# index
# 0      Linear or Logistic Regression, Decision Trees ...
#
# ...

# %%
def df_exploracion(dataframe):
     
     """
     Funcion que nos permite hacer una exploración
     de un dataframe
        
     Args:
      dataframe: es el dataframe que queremos explorar
            
     Returns:
      prints con la exploración del dataframe
                    
     """
    
     print(f"Tamaño del DataFrame: {dataframe.size}")
     print("---------")
     print(f"(El número de filas y columnas del DataFrame: {dataframe.shape}")
     print("----------")
     print(f"Descripción estadística del DataFrame:")
     display(dataframe.describe())
     print("--------")
     print(f"Información general del DataFrame:")
     display(dataframe.info())
     print("--------")
     print(f"Las columnas de este DataFrame son {dataframe.columns}")
     print("----------")
     print(f"Tipo de dato de las columnas de este DataFrame:{dataframe.dtypes}")

# %%
df_exploracion(df_txt)
# Out:
# Tamaño del DataFrame: 675298
# ---------
# (El número de filas y columnas del DataFrame: (25973, 26)
# ----------
# Descripción estadística del DataFrame:
#            Q3               Q4       Q5         Q6      Q8       Q11    Q13  \
# count   25973            25973    25973      25973   24940     24720  24403
# unique     66                7       15          7      13         6      5
# top     India  Master’s degree  Student  1-3 years  Python  A laptop  Never
# freq     7434            10132     6804       7874   20213     16231  16457
#
#              Q15                   Q20             Q21  ...  \
# count      23754                 16325           16251  ...
# unique         9                    18               5  ...
# top     < 1 year  Computers/Technology  0-49 employees  ...
# freq        9163                  4079            5055  ...
#
#                                                       Q41      Q7  \
# ...

# %% [markdown]
# COLUMNAS CON LAS QUE NOS QUEDAMOS: Q3, Q4, Q5, Q6, Q8, Q25

# %%
#¿Cuáles son los paises con más presencia? Filtro por la columna de paises para saber los paises de los que tenemos datos.
paises = pd.DataFrame(df_txt.Q3.value_counts())
paises
# Out:
#                             Q3
# India                     7434
# United States of America  2650
# Other                     1270
# Japan                      921
# China                      814
# ...                        ...
# Kazakhstan                  45
# Norway                      45
# Algeria                     44
# Ethiopia                    43
# Iraq                        43
#
# [66 rows x 1 columns]

# %%
#Nivel de formación
nivel_formativo = pd.DataFrame(df_txt['Q4'].value_counts())
nivel_formativo
# Out:
#                                                        Q4
# Master’s degree                                     10132
# Bachelor’s degree                                    9907
# Doctoral degree                                      2795
# Some college/university study without earning a...   1735
# I prefer not to answer                                627
# No formal education past high school                  417
# Professional doctorate                                360

# %%
posicion = pd.DataFrame(df_txt['Q5'].value_counts())
posicion
# Out:
#                                 Q5
# Student                       6804
# Data Scientist                3616
# Software Engineer             2449
# Other                         2393
# Data Analyst                  2301
# Currently not employed        1986
# Research Scientist            1538
# Machine Learning Engineer     1499
# Business Analyst               968
# Program/Project Manager        849
# Data Engineer                  668
# Product Manager                319
# Statistician                   313
# DBA/Database Engineer          171
# Developer Relations/Advocacy    99

# %%
#Filtro por Data Analyst y Business Analyst que son los que nos interesan
df_posicion = df_txt[(df_txt['Q5'] == 'Business Analyst') | (df_txt ['Q5'] == 'Data Analyst')]
df_posicion.head(2)
# Out:
#                              Q3  \
# index
# 16                      Belgium
# 32     United States of America
#
#                                                       Q4            Q5  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
#
#               Q6      Q8                            Q11    Q13  \
# index
# 16     20+ years  Python                       A laptop  Never
# 32     < 1 years       R  A personal computer / desktop  Never
#
#                                          Q15                        Q20  \
# index
# 16                                 1-2 years              Energy/Mining
# 32     I do not use machine learning methods  Manufacturing/Fabrication
#
#                         Q21  ...  \
# index                        ...
# 16     1000-9,999 employees  ...
# 32        250-999 employees  ...
#
# ...

# %%
#¿Cuáles son los años de experiencia?
años = pd.DataFrame(df_txt['Q6'].value_counts())
años
# Out:
#                              Q6
# 1-3 years                  7874
# < 1 years                  5881
# 3-5 years                  4061
# 5-10 years                 3099
# 10-20 years                2166
# 20+ years                  1860
# I have never written code  1032

# %%
#Respuestas programas
programas = pd.DataFrame(df_posicion['Q8'].value_counts())/df_posicion.shape[0]*100
programas
# Out:
#                    Q8
# Python      67.145916
# SQL         10.676048
# R            8.045274
# C++          1.193025
# Java         0.917712
# C            0.764760
# Other        0.734169
# MATLAB       0.611808
# Julia        0.428266
# None         0.428266
# Javascript   0.397675
# Bash         0.183542
# Swift        0.030590

# %%
salario = pd.DataFrame(df_txt['Q25'].value_counts())
salario.sample(5)
# Out:
#                  Q25
# 10,000-14,999    950
# 30,000-39,999    741
# 7,500-9,999      552
# 150,000-199,999  392
# 125,000-149,999  379
